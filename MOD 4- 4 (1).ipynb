# %%
import pandas as pd

# %%
tele=pd.read_csv("C:/Users/djnag/Downloads/cell2celltrain.csv",encoding = "ISO-8859-1")

# %%
tele.head()
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes           24.00           219.0                  22.0
# 1     3000010   Yes           16.99            10.0                  17.0
# 2     3000014    No           38.00             8.0                  38.0
# 3     3000022    No           82.28          1312.0                  75.0
# 4     3000026   Yes           17.14             0.0                  17.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25             0.0           0.0             -157.0
# 1                   0.00             0.0           0.0               -4.0
# 2                   0.00             0.0           0.0               -2.0
# 3                   1.24             0.0           0.0              157.0
# 4                   0.00             0.0           0.0                0.0
#
#    PercChangeRevenues  ...  ReferralsMadeBySubscriber  IncomeGroup  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(data=tele,x=tele["MonthlyRevenue"])
plt.title("Boxplot of a sample telecom dataset ") #WE ARE USING BOXPLOT ANALYSIS TO DETECT OUR OUTLIERS
# Out:
# Text(0.5, 1.0, 'Boxplot of a sample telecom dataset ')

# %%
outlier1 = tele[tele['MonthlyRevenue']> 216].copy()
print((outlier1['CustomerID']))
#IN THIS WE ARE FILTERING OUT THE MONTHLY REVENUE OUTLIER WHOSE VALUES ARE ABOVE 216 AS IT IS THE 
  #STANDARD REGULATION BY THE TELECOM GOV RULES
# Out:
# 67       3000434
# 77       3000510
# 83       3000570
# 144      3001114
# 161      3001270
#           ...
# 50551    3396038
# 50725    3397458
# 50803    3398054
# 50817    3398162
# 50983    3399490
# Name: CustomerID, Length: 600, dtype: int64

# %%
def boxplot(column):
    sns.boxplot(data=tele,x=tele[f"{column}"])
    plt.title(f"Boxplot of Telecom Industry with varied values {column}")
    plt.show()
#WE ARE NOW CREATING THE BOXPLOTS OF THE RELEVANT OUTLIERS WRT TO OUR MONTHLY REVENUES
#ABOVE 216 AND GET THE BEST OUTLIERS FOR OUR ANALYSIS WITH OUR BOXPLOTS

# %%
boxplot('MonthlyRevenue')
boxplot('MonthlyMinutes')
boxplot('TotalRecurringCharge')
boxplot('DirectorAssistedCalls')
boxplot('OverageMinutes')
boxplot('RoamingCalls')
boxplot('PercChangeMinutes')
boxplot('PercChangeRevenues')
boxplot('ReferralsMadeBySubscriber')
boxplot('IncomeGroup')

# %%
import pandas as pd
import scipy.stats as stats
#WE USE ANOTHER OUTLIER DETECTION METHOD CALLED Z_SCORE

# %%
print(tele.head())
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes           24.00           219.0                  22.0
# 1     3000010   Yes           16.99            10.0                  17.0
# 2     3000014    No           38.00             8.0                  38.0
# 3     3000022    No           82.28          1312.0                  75.0
# 4     3000026   Yes           17.14             0.0                  17.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25             0.0           0.0             -157.0
# 1                   0.00             0.0           0.0               -4.0
# 2                   0.00             0.0           0.0               -2.0
# 3                   1.24             0.0           0.0              157.0
# 4                   0.00             0.0           0.0                0.0
#
#    PercChangeRevenues  ...  ReferralsMadeBySubscriber  IncomeGroup  \
# ...

# %%
tele['Revenue_zscore'] = stats.zscore(tele['MonthlyRevenue'])

# %%
print(tele.head())
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes           24.00           219.0                  22.0
# 1     3000010   Yes           16.99            10.0                  17.0
# 2     3000014    No           38.00             8.0                  38.0
# 3     3000022    No           82.28          1312.0                  75.0
# 4     3000026   Yes           17.14             0.0                  17.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25             0.0           0.0             -157.0
# 1                   0.00             0.0           0.0               -4.0
# 2                   0.00             0.0           0.0               -2.0
# 3                   1.24             0.0           0.0              157.0
# 4                   0.00             0.0           0.0                0.0
#
#    PercChangeRevenues  ...  IncomeGroup  OwnsMotorcycle  \
# ...

# %%
tele['Revenue_zscore'] = (tele.MonthlyRevenue - tele.MonthlyRevenue.mean())/tele.MonthlyRevenue.std(ddof=0)

# %%
print(tele.head())
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes           24.00           219.0                  22.0
# 1     3000010   Yes           16.99            10.0                  17.0
# 2     3000014    No           38.00             8.0                  38.0
# 3     3000022    No           82.28          1312.0                  75.0
# 4     3000026   Yes           17.14             0.0                  17.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25             0.0           0.0             -157.0
# 1                   0.00             0.0           0.0               -4.0
# 2                   0.00             0.0           0.0               -2.0
# 3                   1.24             0.0           0.0              157.0
# 4                   0.00             0.0           0.0                0.0
#
#    PercChangeRevenues  ...  IncomeGroup  OwnsMotorcycle  \
# ...

# %%
print(tele.shape)
# Out:
# (51047, 59)

# %%
print(tele.describe)
# Out:
# <bound method NDFrame.describe of        CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0         3000002   Yes           24.00           219.0                  22.0
# 1         3000010   Yes           16.99            10.0                  17.0
# 2         3000014    No           38.00             8.0                  38.0
# 3         3000022    No           82.28          1312.0                  75.0
# 4         3000026   Yes           17.14             0.0                  17.0
# ...           ...   ...             ...             ...                   ...
# 51042     3399958   Yes             NaN             NaN                   NaN
# 51043     3399974    No           95.17          1745.0                  85.0
# 51044     3399978   Yes             NaN             NaN                   NaN
# 51045     3399990    No             NaN             NaN                   NaN
# 51046     3399994    No             NaN             NaN                   NaN
#
# ...

# %%
from sklearn.ensemble import IsolationForest
import pandas as pd
from matplotlib import pyplot as plt

clf = IsolationForest(max_samples=100, random_state=42)
table = pd.concat([tele['IncomeGroup']], axis=1)
clf.fit(table)
output_table = pd.DataFrame(clf.predict(table))

# %%
a=print(output_table)
# Out:
#        0
# 0     -1
# 1     -1
# 2      1
# 3      1
# 4     -1
# ...   ..
# 51042  1
# 51043 -1
# 51044 -1
# 51045 -1
# 51046 -1
#
# [51047 rows x 1 columns]
